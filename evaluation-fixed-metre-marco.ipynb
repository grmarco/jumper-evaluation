# %% [markdown]
# # Evaluation on fixed-metre poetry

# %% [markdown]
# This Notebook contains the evaluation metrics for Jumper real-time scansion system. It's based on https://github.com/linhd-postdata/rantanplan-evaluation/blob/master/evaluation-fixed-metre.ipynb

# %%
from datetime import datetime
print(f"Last run: {datetime.utcnow().strftime('%B %d %Y - %H:%M:%S')}")
# Out:
# Last run: December 16 2020 - 10:34:21

# %% [markdown]
# ## System info

# %% [markdown]
# Installing dependencies and downloading necessary corpora using [`Averell`](https://pypi.org/project/averell/).

# %%
cat /proc/cpuinfo | grep 'model name' | uniq
# Out:
# model name	: Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz

# %%
cat /proc/meminfo | grep 'MemTotal' | uniq
# Out:
# MemTotal:       16279060 kB

# %% [markdown]
# # Setup

# %%
pip install -q --no-cache https://github.com/linhd-postdata/averell/archive/803685bd7e00cc7def6837f9843ab560085e8fca.zip
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !averell list
# Out:
#   id  name                size      docs    words  granularity    license
# ----  ------------------  ------  ------  -------  -------------  -----------
#    1  Disco V2            22M       4088   381539  stanza         CC-BY
#                                                    line
#    2  Disco V3            28M       4080   377978  stanza         CC-BY
#                                                    line
#    3  Sonetos Siglo       6.8M      5078   466012  stanza         CC-BY-NC
#       de Oro                                       line           4.0
#    4  ADSO 100            128K       100     9208  stanza         CC-BY-NC
#       poems corpus                                 line           4.0
#    5  Poesía Lírica       3.8M       475   299402  stanza         CC-BY-NC
#       Castellana Siglo                             line           4.0
#       de Oro                                       word
#                                                    syllable
#    6  Gongocorpus         9.2M       481    99079  stanza         CC-BY-NC-ND
#                                                    line           3.0
#                                                    word           FR
#                                                    syllable
#    7  Eighteenth Century  2400M     3084  2063668  stanza         CC
#       Poetry Archive                               line           BY-SA
#                                                    word           4.0

# %%
# %%bash
# averell download 3 4 > /dev/null 2>&1
# averell export 3 --granularity line
# mv corpora/line.json corpora/sonnets.json
# averell export 4 --granularity line
# mv corpora/line.json corpora/adso.json
# du -h corpora/*.json
# Out:
# Using corpora folder: './corpora'
# Using corpora folder: './corpora'
# 720K	corpora/adso.json
# 35M	corpora/sonnets.json

# %% [markdown]
# Defining helper functions

# %%
import json
import math
import re
from io import StringIO
import time
import numpy as np
import pandas as pd

def clean_text(string):
    output = string.strip()
    # replacements = (("“", '"'), ("”", '"'), ("//", ""), ("«", '"'), ("»",'"'))
    replacements = (("“", ''), ("”", ''), ("//", ""), ("«", ''), ("»",''))
    for replacement in replacements:
        output = output.replace(*replacement)
    output = re.sub(r'(?is)\s+', ' ', output)
    output = re.sub(r"(\w)-(\w)", r"\1\2", output)  # "Villa-nueva" breaks Navarro-Colorado's system
    return output

# %% [markdown]
# La siguiente función convierte la cadena de sílabas acentuadas y no acentuadas en un vector de acentos. Ejemplo, de '-+---+---+-' a [2,6,10]

# %%
def to_vector(acento):
    acentos = []
    for i,c in enumerate(acento):
        if c == '+':
            acentos.append(i+1)
    return acentos

# %% [markdown]
# # Import

# %%
import jumper

# %% [markdown]
# # Results

# %% [markdown]
# ### Accuracy on ADSO

# %%
adso = pd.DataFrame.from_records(
    json.load(open("corpora/adso.json"))
)[["line_text", "metrical_pattern"]].reset_index(drop=True)
adso.line_text = adso.line_text.apply(clean_text)
adso.metrical_pattern = adso.metrical_pattern.apply(to_vector)
adso
# Out:
#                                    line_text  metrical_pattern
# 0       Yo vi unos ojos bellos, que hirieron  [1, 2, 4, 6, 10]
# 1       con dulce flecha un corazón cuitado,  [2, 4, 5, 8, 10]
# 2          y que para encender nuevo cuidado        [6, 7, 10]
# 3         su fuerza toda contra mí pusieron.     [2, 4, 8, 10]
# 4         Yo vi que muchas veces prometieron  [1, 2, 4, 6, 10]
# ...                                      ...               ...
# 1399     cobró armado y prudente su denuedo,     [2, 3, 6, 10]
# 1400   que sin victorias no contó algún día.  [4, 6, 8, 9, 10]
# 1401        Esto fue don Fadrique de Toledo.     [1, 3, 6, 10]
# 1402    Hoy nos da, desatado en sombra fría,  [1, 3, 6, 8, 10]
# 1403  llanto a los ojos y al discurso miedo.     [1, 4, 8, 10]
#
# [1404 rows x 2 columns]

# %%
start_time = time.time()
analisis_adso = jumper.escandir_lista_versos(adso.line_text.tolist())
time_adso = time.time() - start_time

# %%
adso_output_df = pd.DataFrame.from_records(analisis_adso, columns=['Verso', 'Verso etiquetado', "Sílabas", "acentos", 'Sin acentos extrarrítmicos', 'Tipo', 'Coincidencia'])
adso_output_df
# Out:
#                                        Verso  \
# 0       Yo vi unos ojos bellos, que hirieron
# 1       con dulce flecha un corazón cuitado,
# 2          y que para encender nuevo cuidado
# 3         su fuerza toda contra mí pusieron.
# 4         Yo vi que muchas veces prometieron
# ...                                      ...
# 1399     cobró armado y prudente su denuedo,
# 1400   que sin victorias no contó algún día.
# 1401        Esto fue don Fadrique de Toledo.
# 1402    Hoy nos da, desatado en sombra fría,
# 1403  llanto a los ojos y al discurso miedo.
#
#                             Verso etiquetado  Sílabas           acentos  \
# 0      yo vi unos ojos bellos que   hirieron       11  [1, 2, 4, 6, 10]
# 1       con dulce flecha un corazón cuitado,       11  [2, 4, 5, 8, 10]
# 2          y que para encender nuevo cuidado       11        [6, 7, 10]
# 3         su fuerza toda contra mí pusieron.       11     [2, 4, 8, 10]
# 4         Yo vi que muchas veces prometieron       11  [1, 2, 4, 6, 10]
# ...                                      ...      ...               ...
# 1399     cobró armado y prudente su denuedo,       11     [2, 3, 6, 10]
# 1400   que sin victorias no contó algún día.       11  [4, 6, 8, 9, 10]
# 1401        Esto fue don Fadrique de Toledo.       11     [1, 3, 6, 10]
# 1402    Hoy nos da, desatado en sombra fría,       11  [1, 3, 6, 8, 10]
# 1403  llanto a los ojos y al discurso miedo.       11     [1, 4, 8, 10]
#
#      Sin acentos extrarrítmicos                             Tipo  Coincidencia
# 0                 [2, 4, 6, 10]       Endecasílabo heroico corto           0.9
# 1                 [2, 4, 8, 10]  Endecasílabo sáfico largo pleno           0.9
# 2                       [6, 10]          Endecasílabo vacío puro           0.9
# 3                 [2, 4, 8, 10]  Endecasílabo sáfico largo pleno           1.0
# 4                 [2, 4, 6, 10]       Endecasílabo heroico corto           0.9
# ...                         ...                              ...           ...
# 1399                 [2, 6, 10]        Endecasílabo heroico puro           0.9
# 1400              [4, 6, 8, 10]        Endecasílabo sáfico largo           0.9
# 1401              [1, 3, 6, 10]      Endecasílabo melódico corto           1.0
# 1402           [1, 3, 6, 8, 10]      Endecasílabo melódico pleno           1.0
# 1403              [1, 4, 8, 10]   Endecasílabo sáfico puro pleno           1.0
#
# [1404 rows x 7 columns]

# %%
accuracy_adso = sum(adso_output_df.acentos == adso.metrical_pattern) / adso.metrical_pattern.size

# %%
print(f"Jumper scansion on ADSO: {accuracy_adso:.2f} ({time_adso:.2f}s)")
# Out:
# Jumper scansion on ADSO: 0.95 (0.33s)

# %% [markdown]
# ### Accuracy on Sonnets

# %%
sonnets = pd.DataFrame.from_records(
    json.load(open("corpora/sonnets.json"))
).query("manually_checked == True")[["line_text", "metrical_pattern"]].reset_index(drop=True)
sonnets.line_text = sonnets.line_text.apply(clean_text)
sonnets.metrical_pattern = sonnets.metrical_pattern.apply(to_vector)
sonnets
# Out:
#                                   line_text  metrical_pattern
# 0        Cuando la alegre y dulce primavera        [4, 6, 10]
# 1          a partir sus riquezas comenzaba,        [3, 6, 10]
# 2         y de los verdes campos desterraba        [4, 6, 10]
# 3         aquella estéril sequedad primera,     [2, 4, 8, 10]
# 4      un pastor triste y solo en la ribera  [1, 3, 4, 6, 10]
# ...                                     ...               ...
# 10264  y en tus labios purpúrea competencia        [3, 6, 10]
# 10265     agora al alba y al clavel ofrece,     [2, 4, 8, 10]
# 10266    la edad, con invisible diligencia,        [2, 6, 10]
# 10267        en el común ocaso lo oscurece;        [4, 6, 10]
# 10268  ¿cuándo tendrá para volver licencia?     [1, 4, 8, 10]
#
# [10269 rows x 2 columns]

# %%
start_time = time.time()
analisis_sonnets = jumper.escandir_lista_versos(sonnets.line_text.tolist())
time_sonnets = time.time() - start_time

# %%
sonnets_output_df = pd.DataFrame.from_records(analisis_sonnets, columns=['Verso', 'Verso etiquetado', "Sílabas", "acentos", 'Sin acentos extrarrítmicos', 'Tipo', 'Coincidencia'])
sonnets_output_df
# Out:
#                                       Verso  \
# 0        Cuando la alegre y dulce primavera
# 1          a partir sus riquezas comenzaba,
# 2         y de los verdes campos desterraba
# 3         aquella estéril sequedad primera,
# 4      un pastor triste y solo en la ribera
# ...                                     ...
# 10264  y en tus labios purpúrea competencia
# 10265     agora al alba y al clavel ofrece,
# 10266    la edad, con invisible diligencia,
# 10267        en el común ocaso lo oscurece;
# 10268  ¿cuándo tendrá para volver licencia?
#
#                            Verso etiquetado  Sílabas           acentos  \
# 0        Cuando la alegre y dulce primavera       11        [4, 6, 10]
# 1          a partir sus riquezas comenzaba,       11        [3, 6, 10]
# 2         y de los verdes campos desterraba       11        [4, 6, 10]
# 3         aquella estéril sequedad primera,       11     [2, 4, 8, 10]
# 4      un pastor triste y solo en la ribera       11  [1, 3, 4, 6, 10]
# ...                                     ...      ...               ...
# 10264  y en tus labios purpúr#a competencia       11        [3, 6, 10]
# 10265    agora al alba y   al clavel ofrece       11     [2, 4, 8, 10]
# 10266    la edad, con invisible diligencia,       11        [2, 6, 10]
# 10267        en el común ocaso lo oscurece;       11        [4, 6, 10]
# 10268  ¿cuándo tendrá para volver licencia?       11     [1, 4, 8, 10]
#
#       Sin acentos extrarrítmicos                             Tipo  \
# 0                     [4, 6, 10]        Endecasílabo sáfico corto
# 1                     [3, 6, 10]       Endecasílabo melódico puro
# 2                     [4, 6, 10]        Endecasílabo sáfico corto
# 3                  [2, 4, 8, 10]  Endecasílabo sáfico largo pleno
# 4                  [1, 3, 6, 10]      Endecasílabo melódico corto
# ...                          ...                              ...
# 10264                 [3, 6, 10]       Endecasílabo melódico puro
# 10265              [2, 4, 8, 10]  Endecasílabo sáfico largo pleno
# 10266                 [2, 6, 10]        Endecasílabo heroico puro
# 10267                 [4, 6, 10]        Endecasílabo sáfico corto
# 10268              [1, 4, 8, 10]   Endecasílabo sáfico puro pleno
#
#        Coincidencia
# 0               1.0
# 1               1.0
# 2               1.0
# 3               1.0
# 4               0.9
# ...             ...
# 10264           1.0
# 10265           1.0
# 10266           1.0
# 10267           1.0
# 10268           1.0
#
# [10269 rows x 7 columns]

# %%
accuracy_sonnets = sum(sonnets_output_df.acentos == sonnets.metrical_pattern) / sonnets.metrical_pattern.size

# %%
print(f"Jumper scansion on Sonnets: {accuracy_sonnets:.2f} ({time_sonnets:.2f}s)")
# Out:
# Jumper scansion on Sonnets: 0.95 (2.48s)

# %% [markdown]
# # Failure analysis

# %%
errores = sonnets_output_df['acentos'] != sonnets.metrical_pattern
df_errores = sonnets_output_df.loc[errores].copy()
df_errores['Data set'] = sonnets.loc[errores, 'metrical_pattern']
df_errores
# Out:
#                                          Verso  \
# 11        que, cuanto más sin pena se hallare,
# 12         si a Silvia la cruel pastora viere,
# 66     que, puesto que tu vivo ardor te mueve,
# 81      ¡Oh gran consuelo a mi esperanza vana,
# 86       reqüiescant in bello, que no in pace,
# ...                                        ...
# 10160       básteme a mí sentir, ya que no veo
# 10181   Ya que cantar en estas frescas sombras
# 10192         Minerva eternamente la acompaña.
# 10202         y el Amor por la mano te guiaba.
# 10233     y en su consejo y brazo, felizmente,
#
#                               Verso etiquetado  Sílabas              acentos  \
# 11        que cuanto más sin pena se   hallare       11           [4, 6, 10]
# 12        si   a silvia la cruel pastora viere       11        [3, 6, 8, 10]
# 66     que, puesto que tu vivo ardor te mueve,       11        [2, 6, 8, 10]
# 81      ¡Oh gran consuelo a mi esperanza vana,       11     [1, 2, 4, 8, 10]
# 86       reqüiescant in bello, que no in pace,       11     [4, 5, 6, 9, 10]
# ...                                        ...      ...                  ...
# 10160       básteme a mí sentir, ya que no veo       11  [1, 4, 6, 7, 9, 10]
# 10181   Ya que cantar en estas frescas sombras       11     [1, 4, 6, 8, 10]
# 10192         Minerva eternamente la acompaña.       11        [2, 4, 6, 10]
# 10202          y el amor por la mano te gi~aba       11           [3, 6, 10]
# 10233     y en su consejo y brazo, felizmente,       11        [4, 6, 9, 10]
#
#       Sin acentos extrarrítmicos                             Tipo  \
# 11                    [4, 6, 10]        Endecasílabo sáfico corto
# 12                 [3, 6, 8, 10]      Endecasílabo melódico largo
# 66                 [2, 6, 8, 10]       Endecasílabo heroico largo
# 81                 [1, 4, 8, 10]   Endecasílabo sáfico puro pleno
# 86                    [4, 6, 10]        Endecasílabo sáfico corto
# ...                          ...                              ...
# 10160              [1, 4, 6, 10]  Endecasílabo sáfico corto pleno
# 10181           [1, 4, 6, 8, 10]        Endecasílabo sáfico pleno
# 10192              [2, 4, 6, 10]       Endecasílabo heroico corto
# 10202                 [3, 6, 10]       Endecasílabo melódico puro
# 10233                 [4, 6, 10]        Endecasílabo sáfico corto
#
#        Coincidencia          Data set
# 11              1.0     [2, 4, 6, 10]
# 12              1.0     [2, 6, 8, 10]
# 66              1.0        [6, 8, 10]
# 81              0.9     [1, 4, 8, 10]
# 86              0.8     [2, 5, 8, 10]
# ...             ...               ...
# 10160           0.8  [1, 4, 6, 9, 10]
# 10181           1.0     [4, 6, 8, 10]
# 10192           1.0        [2, 6, 10]
# 10202           1.0        [4, 7, 10]
# 10233           0.9        [4, 6, 10]
#
# [546 rows x 8 columns]

# %% [raw]
# df_errores[['Verso','Verso etiquetado','Sílabas','metrical_pattern']].sample(100).to_csv('errores-fijo.csv')
